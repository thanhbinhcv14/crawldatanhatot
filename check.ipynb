# %%
import pandas as pd

# %%
# Đường dẫn đến tệp CSV của bạn
file_path = 'nhatot\\spiders\\nhatotdata.csv'

# %%
# Đọc tệp CSV vào DataFrame
df = pd.read_csv(file_path)

# %%
df.shape
# Out:
# (1669, 11)

# %%
display(df)
# Out:
#                                                    name          price  \
# 0     CĂN GÓC 2 BAN CÔNG FULL NỘI THẤT VÀO Ở NGAY GI...        1,38 tỷ
# 1     BÁN NHÀ CẤP 4 MT TRẦN XUÂN SOẠN - KHUÊ TRUNG -...         4,3 tỷ
# 2              Căn 2pn2vs+1 toà GS3 Vinhomes Smart City           4 tỷ
# 3     BÁN CĂN HỘ SÁT Q7 250m2 FULL NỘI THẤT 6 PN GIÁ...        5,15 tỷ
# 4     Akari City - Chiết khấu lên đến 710tr - Ưu đãi...         3,7 tỷ
# 5     chính chù bán đất hẻm xe hơi gần Biển phường 1...      165 triệu
# 6     CẦU GIẤY/35M2 - 6.xx TỶ NHÀ ĐẸP Ở NGAY - GẦN P...         6,6 tỷ
# 7     Bán rẻ nhà Hóc Môn ngang 5m Phan văn Đối gần k...        8,05 tỷ
# 8     💕 Kiệt oto tránh nhau 7met , 96m2, Hoàng Văn T...        2,55 tỷ
# 9     cần bán gấp đất Vĩnh Phú,  Thuận An, 117m2 giá...      650 triệu
# 10    NHÀ SHR 2 TẦNG 51m2 METRO NGUYỄN THỊ KIỂU TÂN ...        3,55 tỷ
# 11    Chính Chủ bán lô Mặt tiền Đ.Tân Hiệp 28, DT 20...         1,8 tỷ
# ...
